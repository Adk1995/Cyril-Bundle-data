# %%
import os
from PIL import Image
import pandas as pd
import tqdm

# %%
products = {}
product_ID = []
base_url = 'data/300ppi/'

# %%
image = Image.open('data/300ppi/9800/00071_1.png')
image = image.resize((2500,1950), Image.ANTIALIAS)
rgb= image.convert('RGB')
rgb.save('data/color.jpg')
print(image.size[0],image.format)
# Out:
# 2500 None

# %%
df_BasicInfo = pd.read_csv('data/BasicProductDetails.csv')
df_BasicInfo['Company ID'] = df_BasicInfo['Company ID'].astype('str')
df_BasicInfo['Product ID'] = df_BasicInfo['Product ID'].astype('str').str.zfill(5)
df_BasicInfo.head()
# Out:
#    Unnamed: 0          UPC      ID               Manufacturer  \
# 0           2  43000029220  243996          Kraft Foods, Inc.
# 1           3  19600050308  402216   Pinnacle Foods Group LLC
# 2           4  41331037822  397371           Goya Foods, Inc.
# 3           5  14100078678  620865    Pepperidge Farm Tim Tam
# 4           6  87684001066  399630  Kraft Heinz Foods Company
#
#                         Brand  \
# 0               Maxwell House
# 1                     Celeste
# 2                        Goya
# 3  Pepperidge Farm® Goldfish®
# 4                   Capri Sun
#
#                                  Product Description Vegan Vegetarian  \
# 0  Maxwell House Ground Coffee The Original Roast...   NaN        NaN
# 1            Celeste Pizza For One Original 4 Cheese   NaN        NaN
# 2           Goya Sason Coriander & Annatto Seasoning   NaN        NaN
# 3  Pepperidge Farm® Goldfish® Cheddar Crackers, 2...   NaN        NaN
# 4             Capri Sun Juice Drink Lemonade - 10 CT   NaN        NaN
#
#   Nut Free Lactose Free Company ID Product ID
# 0      NaN          NaN      43000      02922
# 1      NaN          NaN      19600      05030
# 2      NaN          NaN      41331      03782
# 3        Y          NaN      14100      07867
# 4      NaN          NaN      87684      00106

# %%
def create_product_dict(df_Info):
    products.clear()
    for index,company in enumerate(df_Info['Company ID']):
        if company in products.keys():
            products[company].append(df_Info['Product ID'][index])
        else:
            products[company] = [df_Info['Product ID'][index]]

# %%
create_product_dict(df_BasicInfo)
products
# Out:
# {'43000': ['02922',
#   '95563',
#   '20001',
#   '05401',
#   '20433',
#   '04574',
#   '20651',
#   '20691',
#   '04209',
#   '95531',
#   '04648',
#   '28532',
#   '20445',
#   '27678',
#   '00037',
#   '95562',
#   '20431'],
#  '19600': ['05030', '04620', '04580', '04610', '04500', '04630'],
#  '41331': ['03782',
#   '09060',
#   '12420',
#   '02163',
#   '02465',
#   '02787',
#   '12435',
#   '02476',
#   '04942',
#   '12001',
#   '02662',
#   '04943'],
#  '14100': ['07867',
#   '07061',
#   '08548',
#   '07412',
#   '09506',
#   '07033',
#   '07083',
#   '08550',
#   '08598',
#   '08599',
#   '07111',
#   '07161',
#   '07187',
#   '07009',
#   '08539',
#   '09655',
#   '08547',
#   '07472'],
#  '87684': ['00106', '00107'],
#  '73731': ['00830', '00415', '00419'],
#  '63435': ['89111'],
#  '41196': ['01032', '01022', '91401', '01088', '01013', '01012', '40482'],
#  '50000': ['57795',
#   '57017',
#   '57056',
#   '42914',
#   '04080',
#   '29261',
#   '42984',
#   '57988',
#   '42364',
#   '42194',
#   '42964',
#   '42154',
#   '42954',
#   '10368',
#   '42944',
#   '42324',
#   '10206',
#   '42184',
#   '42924',
#   '29259',
#   '58570',
#   '42994',
#   '43464',
#   '10042',
#   '57366',
#   '58216',
#   '57395',
#   '42934',
#   '42874',
#   '29327',
#   '42444',
#   '29263',
#   '57058',
#   '42694',
#   '57500',
#   '42494',
#   '04060',
#   '21520',
#   '42564',
#   '42894',
#   '29331',
#   '42054',
#   '58210',
#   '42904',
#   '57402',
#   '00124',
#   '42794',
#   '57798',
#   '41220',
#   '57049'],
#  '76183': ['00357', '16374', '16356', '64356', '64357'],
#  '44000': ['03338',
#   '02829',
#   '03215',
#   '03202',
#   '00674',
#   '02859',
#   '00225',
#   '03039',
#   '03219',
#   '03223',
#   '01777',
#   '03211',
#   '03327',
#   '02681',
#   '00055'],
#  '71730': ['00715'],
#  '13900': ['50001', '50051'],
#  '83900': ['00649', '00597', '00575', '00576', '00538'],
#  '21273': ['10012'],
#  '73420': ['00015', '00011'],
#  '25000': ['04628',
#   '05425',
#   '04772',
#   '05544',
#   '04821',
#   '05416',
#   '02653',
#   '05542',
#   '05543',
#   '04786',
#   '05433'],
#  '49000': ['02469',
#   '00548',
#   '00044',
#   '05545',
#   '05017',
#   '05437',
#   '05071',
#   '05541',
#   '04584',
#   '01834',
#   '05028',
#   '03165',
#   '04574',
#   '00463',
#   '02470',
#   '04523',
#   '05539',
#   '05011',
#   '00594',
#   '05012',
#   '02468',
#   '04573',
#   '01463',
#   '02890',
#   '04575',
#   '05010',
#   '05014',
#   '05072',
#   '05436',
#   '05543',
#   '05016',
#   '06406',
#   '05537',
#   '05199'],
#  '79606': ['01015', '10645', '01025'],
#  '71673': ['02050', '00111', '02120'],
#  '36632': ['03812', '03753', '03273', '01103', '02601', '00260'],
#  '21000': ['30192',
#   '61689',
#   '12382',
#   '02322',
#   '65320',
#   '61531',
#   '65893',
#   '00522',
#   '61247',
#   '61541',
#   '60465',
#   '02649',
#   '61526',
#   '05517',
#   '60269',
#   '60464',
#   '61527',
#   '61161',
#   '01088',
#   '01328',
#   '12164',
#   '61223',
#   '00901',
#   '61144'],
#  '38000': ['76862',
#   '26066',
#   '59923',
#   '59663',
#   '40260',
#   '31120',
#   '39118',
#   '00110',
#   '57600',
#   '31829',
#   '39120',
#   '59655',
#   '00120',
#   '31720',
#   '39125',
#   '40290',
#   '59644'],
#  '71091': ['00007'],
#  '51500': ['24177', '00686', '60441', '20441', '79480', '01229', '79590'],
#  '75185': ['00003', '00006', '00004', '00501', '00700', '00001'],
#  '41789': ['00121', '00621', '00125', '00231', '00122'],
#  '36000': ['25829',
#   '37390',
#   '37387',
#   '37387',
#   '37403',
#   '28790',
#   '25875',
#   '45248',
#   '29388',
#   '37388',
#   '25866'],
#  '44700': ['09219',
#   '36000',
#   '02132',
#   '01988',
#   '06647',
#   '09205',
#   '00744',
#   '36035',
#   '06662',
#   '00674',
#   '36114',
#   '36001',
#   '02455',
#   '00677',
#   '09240',
#   '02411',
#   '01990',
#   '01991',
#   '36002',
#   '03128',
#   '36147',
#   '36113'],
#  '48121': ['18411',
#   '11701',
#   '27707',
#   '10208',
#   '21657',
#   '27620',
#   '29208',
#   '18407'],
#  '34000': ['40211', '14830', '14600', '29005', '40568'],
#  '37000': ['95035',
#   '08875',
#   '95007',
#   '28577',
#   '12784',
#   '40154',
#   '32024',
#   '34864',
#   '43357'],
#  '46000': ['82121',
#   '28876',
#   '29549',
#   '28732',
#   '28875',
#   '81101',
#   '28734',
#   '28869',
#   '81151'],
#  '16000': ['27569',
#   '43472',
#   '43980',
#   '42040',
#   '19430',
#   '43054',
#   '27707',
#   '27706',
#   '14155',
#   '26460',
#   '14154',
#   '19726',
#   '27700',
#   '18910',
#   '10610',
#   '27568',
#   '45701',
#   '42371',
#   '14159',
#   '30650',
#   '15910',
#   '27511',
#   '27532',
#   '27565',
#   '43473',
#   '45723',
#   '27503',
#   '27534',
#   '26470',
#   '14156',
#   '30570',
#   '30630'],
#  '36200': ['00444', '21931', '00440', '21929', '21932', '00464'],
#  '24600': ['01001'],
#  '70346': ['00009'],
#  '27000': ['39007'],
#  '71300': ['00008', '00035', '00076'],
#  '22000': ['00484', '15933'],
#  '49200': ['05600', '05675', '05100', '04570'],
#  '77901': ['00781'],
#  '18000': ['00501',
#   '00182',
#   '00317',
#   '00338',
#   '00468',
#   '81772',
#   '00159',
#   '00211',
#   '28794',
#   '00210',
#   '00401',
#   '00420',
#   '00724'],
#  '73410': ['31200',
#   '31025',
#   '01375',
#   '00305',
#   '01355',
#   '13546',
#   '13547',
#   '00026'],
#  '73491': ['51000', '20200', '09500'],
#  '80000': ['50527', '49524', '00674', '00673'],
#  '41390': ['00002'],
#  '70662': ['06003'],
#  '72945': ['60134', '61241', '70544', '60136'],
#  '82657': ['50060', '41157', '33412'],
#  '78000': ['15246',
#   '15245',
#   '14846',
#   '20646',
#   '14645',
#   '21416',
#   '15345',
#   '08239',
#   '00386',
#   '00976',
#   '15288'],
#  '15700': ['20966', '45010'],
#  '24300': ['04120', '04102', '04101', '04106'],
#  '51000': ['07874', '07546', '23262'],
#  '13000': ['79890',
#   '79830',
#   '79630',
#   '00124',
#   '00113',
#   '79850',
#   '79820',
#   '00112',
#   '79860'],
#  '52100': ['09860',
#   '00256',
#   '00698',
#   '00626',
#   '09030',
#   '09150',
#   '00438',
#   '00251'],
#  '38616': ['38768'],
#  '86600': ['75077', '00025', '00925', '00020'],
#  '15100': ['02625', '02624'],
#  '12000': ['80996'],
#  '14800': ['00007', '00023', '00010', '64608'],
#  '41148': ['47372', '47375'],
#  '77782': ['00276'],
#  '70074': ['55958'],
#  '20735': ['11057', '11057', '11057', '11057'],
#  '72322': ['54030'],
#  '72030': ['01353',
#   '00018',
#   '00021',
#   '01342',
#   '00237',
#   '00225',
#   '01339',
#   '01108',
#   '01108',
#   '01108',
#   '01108',
#   '00161'],
#  '33400': ['60135',
#   '60173',
#   '60128',
#   '60179',
#   '61280',
#   '61282',
#   '60119',
#   '60176',
#   '60108',
#   '61283'],
#  '19800': ['03674', '03663', '03667'],
#  '31000': ['10102', '30744', '18464'],
#  '54800': ['03080', '03176', '03077', '03076'],
#  '44500': ['34171', '05298', '34172', '34122'],
#  '43500': ['60004'],
#  '70800': ['04125', '04118'],
#  '14500': ['01098'],
#  '70085': ['06010', '06012'],
#  '41208': ['01060'],
#  '54100': ['00060'],
#  '54000': ['10060', '15029', '36371', '36374', '12219', '36369'],
#  '75199': ['00133', '00190'],
#  '75720': ['00200', '00005'],
#  '34500': ['15150', '15136', '19410'],
#  '58496': ['72306'],
#  '64144': ['32160'],
#  '46675': ['01350'],
#  '23400': ['35001'],
#  '16447': ['10090'],
#  '13120': ['01251'],
#  '15665': ['60100', '77045'],
#  '39000': ['00820', '01892', '00890', '01021', '00800'],
#  '15000': ['01212'],
#  '72745': ['06830'],
#  '41164': ['00022'],
#  '71040': ['02118', '06504', '00060', '06330'],
#  '78902': ['41120'],
#  '73040': ['00405'],
#  '28400': ['05597', '56466', '56463', '09632', '01109', '08359', '14741'],
#  '11193': ['13101'],
#  '54400': ['00005'],
#  '29700': ['00141', '00145', '00147', '00146'],
#  '70796': ['30003'],
#  '37466': ['01584'],
#  '24842': ['01131'],
#  '70470': ['00323',
#   '00307',
#   '00651',
#   '13772',
#   '48605',
#   '47639',
#   '45578',
#   '43579',
#   '43329',
#   '43332',
#   '43548',
#   '43333',
#   '43331',
#   '13778'],
#  '31200': ['01605'],
#  '48000': ['00245', '03355', '00086'],
#  '41129': ['01003'],
#  '35000': ['44676'],
#  '47800': ['33011'],
#  '47500': ['00445'],
#  '41800': ['71500', '71600'],
#  '20169': ['22233', '22150'],
#  '25500': ['00384', '20421'],
#  '11233': ['08711', '08704', '08701'],
#  '24000': ['16286', '04106', '16317', '34346'],
#  '41740': ['00003'],
#  '76301': ['84504'],
#  '70847': ['81126', '81116'],
#  '41333': ['82501'],
#  '72180': ['63983'],
#  '20000': ['00110'],
#  '44100': ['10107'],
#  '41234': ['11376'],
#  '33776': ['01171', '01100'],
#  '23000': ['35145', '35195'],
#  '43301': ['30519'],
#  '70328': ['00523'],
#  '41262': ['28443'],
#  '38900': ['00143'],
#  '24100': ['10685'],
#  '30100': ['50656'],
#  '40000': ['00032', '50531'],
#  '29000': ['07325', '01665'],
#  '28300': ['00405'],
#  '13130': ['00612'],
#  '71330': ['60149', '60138'],
#  '48500': ['01830'],
#  '73406': ['62750'],
#  '17800': ['14595'],
#  '79100': ['51254'],
#  '72979': ['00416'],
#  '37600': ['22318', '24193'],
#  '70575': ['04009'],
#  '21131': ['50475'],
#  '36600': ['81331'],
#  '22655': ['30301'],
#  '70272': ['23204', '23202'],
#  '78913': ['18606'],
#  '70200': ['01065', '01066'],
#  '25800': ['02320'],
#  '27300': ['10017'],
#  '72350': ['00001'],
#  '72251': ['00105'],
#  '71305': ['05525', '05526'],
#  '42421': ['00595'],
#  '66086': ['08020'],
#  '30271': ['03407'],
#  '73390': ['00011'],
#  '11140': ['87102'],
#  '39400': ['01606'],
#  '13562': ['00004', '30084'],
#  '71871': ['54860'],
#  '51600': ['00001'],
#  '41617': ['00225'],
#  '59290': ['57322'],
#  '78700': ['80162'],
#  '26200': ['11700'],
#  '9800': ['00071'],
#  '13800': ['15173'],
#  '71448': ['30014'],
#  '71921': ['13389']}

# %%
def fetch_images(product_dict):
    height = 0
    length = 0
    width =0
    dim = []
    dim1 = []
    image_exts = ['_1.png','_2.png','_3.png','_7.png','_8.png','_9.png']
    sample = ['19600', '41331', '14100', '87684']
    for key in tqdm.tqdm(product_dict.keys()):
        company_id = key
        for item in product_dict[company_id]:
            height = 0
            length = 0
            width = 0
            for ext in image_exts:
                if os.path.exists(base_url+company_id+'/'+item+ext):
                    image = Image.open(base_url+company_id+'/'+item+ext)
                    if '_1.png' in ext:
                        height = image.size[1]
                        width = image.size[0]
                        image = image.convert('RGB')
                        image.save(base_url+company_id+'/'+item+'_1.jpg')
                            
                    elif '_2.png' in ext:
                        length = image.size[0]
                        dim.append(length)
                        dim.append(height)
                        if height>0:
                            image = image.resize(dim)
                        image = image.convert('RGB')
                        image.save(base_url+company_id+'/'+item+'_2.jpg')
                        del dim[:]
                    
                    elif '_3.png' in ext:
                        dim.append(width)
                        dim.append(length)
                        if width>0 and length>0:
                            image = image.resize(dim, Image.ANTIALIAS)
                        image = image.convert('RGB')
                        image.save(base_url+company_id+'/'+item+'_3.jpg')
                        del dim[:]
                        
                    elif '_7.png' in ext:
                        dim.append(width)
                        dim.append(height)
                        if height>0 and width>0:
                            image = image.resize(dim,Image.ANTIALIAS)
                        image = image.convert('RGB')
                        image.save(base_url+company_id+'/'+item+'_7.jpg')
                        del dim[:]
                        
                    elif '_8.png' in ext:
                        dim.append(length)
                        dim.append(height)
                        if height>0 and length>0:
                            image = image.resize(dim,Image.ANTIALIAS)
                        image = image.convert('RGB')
                        image.save(base_url+company_id+'/'+item+'_8.jpg')
                        del dim[:]
                    
                    elif '_9.png' in ext:
                        dim.append(width)
                        dim.append(length)
                        if width>0 and length>0:
                            image = image.resize(dim,Image.ANTIALIAS)
                        image = image.convert('RGB')
                        image.save(base_url+company_id+'/'+item+'_9.jpg')
                        del dim[:]

# %%
fetch_images(products)
# Out:
#   0%|          | 0/171 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 1/171 [00:54<2:33:52, 54.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 2/171 [01:14<2:03:57, 44.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 3/171 [01:37<1:45:56, 37.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 4/171 [02:42<2:07:23, 45.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 5/171 [02:49<1:35:11, 34.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▎         | 6/171 [02:58<1:13:24, 26.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 7/171 [03:05<56:55, 20.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▍         | 8/171 [03:14<46:39, 17.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 9/171 [06:33<3:13:26, 71.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         |